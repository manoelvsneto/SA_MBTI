# %%
# =========================================================
# Script to calculate the kw_summary table
# (Kruskal–Wallis + epsilon-squared) from CSV
#
# Input: data.csv
# Output:
#    - DataFrame kw_summary
#    - LaTeX block ready to paste into the paper
# =========================================================

import pandas as pd
import numpy as np
from scipy.stats import kruskal

# ---------- Load file ----------
filename = "data.csv"
print("Loading file:", filename)

df = pd.read_csv(filename)
df.columns = [c.strip() for c in df.columns]
print("Columns found:", list(df.columns))
print("Rows:", len(df))

# ---------- Config ----------
# Group columns to test
GROUP_COL_CANDIDATES = ["Group", "MBTI", "GENDER", "Profile"]

# Outcome columns (metrics from CSV)
# REQ = Nota Requisitos
# DEV = Nota Desenvolvimento  
# PROVA = Prova Teórica
# NOTA FINAL = Nota Final
OUTCOME_COLS = ["REQ", "DEV", "PROVA", "NOTA FINAL"]

# ---------- Helpers ----------
def find_first_existing_col(df: pd.DataFrame, candidates: list[str]) -> str:
    for c in candidates:
        if c in df.columns:
            return c
    raise KeyError(
        f"None of the candidate columns were found.\n"
        f"Candidates: {candidates}\n"
        f"Columns in file: {list(df.columns)}"
    )

def to_numeric_series(s: pd.Series) -> pd.Series:
    # converts strings with comma/spaces; forces NaN when not numeric
    s2 = (
        s.astype(str)
         .str.replace("\u00a0", " ", regex=False)  # NBSP
         .str.replace(",", ".", regex=False)
         .str.strip()
    )
    return pd.to_numeric(s2, errors="coerce")

def epsilon_squared_from_H(H: float, k: int, N: int) -> float:
    """
    Epsilon-squared for Kruskal–Wallis:
      eps2 = (H - k + 1) / (N - k)
    Can become negative when H < k-1; we truncate to 0.
    """
    if N <= k:
        return float("nan")
    eps2 = (H - k + 1) / (N - k)
    return float(max(0.0, eps2))

def escape_latex(s: str) -> str:
    repl = {
        "\\": r"\textbackslash{}",
        "&": r"\&",
        "%": r"\%",
        "$": r"\$",
        "#": r"\#",
        "_": r"\_",
        "{": r"\{",
        "}": r"\}",
        "~": r"\textasciitilde{}",
        "^": r"\textasciicircum{}",
    }
    out = str(s)
    for k, v in repl.items():
        out = out.replace(k, v)
    return out

def fmt_p(p: float) -> str:
    if pd.isna(p):
        return "--"
    if p < 0.001:
        return "<0.001"
    return f"{p:.3f}"

def fmt_eps(eps: float) -> str:
    if pd.isna(eps):
        return "--"
    return f"{eps:.3f}"

# ---------- Process each group column ----------
outcome_cols = [c for c in OUTCOME_COLS if c in df.columns]
if not outcome_cols:
    raise KeyError(
        f"No outcome column found.\n"
        f"Expected: {OUTCOME_COLS}\n"
        f"Columns in file: {list(df.columns)}"
    )

print("\nOutcome columns found:", outcome_cols)

# Metric names for display
metric_names = {
    "REQ": "Nota Requisitos",
    "DEV": "Nota Desenvolvimento",
    "PROVA": "Prova Teórica",
    "NOTA FINAL": "Nota Final"
}

for group_col in GROUP_COL_CANDIDATES:
    if group_col not in df.columns:
        print(f"\n[WARNING] Group column '{group_col}' not found. Skipping.")
        continue
    
    print("\n" + "="*80)
    print(f"ANALYSIS BY: {group_col}")
    print("="*80)
    
    # Normalize group column
    df[group_col] = df[group_col].astype(str).str.strip()
    
    rows = []
    for outcome in outcome_cols:
        tmp = df[[group_col, outcome]].copy()
        tmp[outcome] = to_numeric_series(tmp[outcome])

        tmp = tmp.dropna(subset=[outcome])
        tmp = tmp[tmp[group_col].notna() & (tmp[group_col] != "")]

        groups = []
        group_names = []
        for g, sub in tmp.groupby(group_col):
            vals = sub[outcome].to_numpy(dtype=float)
            if len(vals) > 0:
                groups.append(vals)
                group_names.append(g)

        k = len(groups)
        N = int(tmp.shape[0])

        if k < 2:
            H = np.nan
            p = np.nan
            eps2 = np.nan
        else:
            H, p = kruskal(*groups, nan_policy="omit")
            eps2 = epsilon_squared_from_H(H, k, N)

        rows.append(
            {
                "Variable": metric_names.get(outcome, outcome),
                "Groups (k)": k,
                "N": N,
                "H (KW)": float(H) if pd.notna(H) else np.nan,
                "p (KW)": float(p) if pd.notna(p) else np.nan,
                "epsilon^2": float(eps2) if pd.notna(eps2) else np.nan,
                "Groups found": ", ".join(group_names),
            }
        )

    kw_df = pd.DataFrame(rows)

    print(f"\n=== Kruskal–Wallis Summary: {group_col} ===")
    display(kw_df[["Variable", "Groups (k)", "N", "p (KW)", "epsilon^2", "Groups found"]])

    # ---------- Generate LaTeX table ----------
    latex_lines = []
    latex_lines.append(r"\begin{table}[t]")
    latex_lines.append(r"\centering")
    latex_lines.append(r"\small")
    latex_lines.append(f"\\caption{{Inferential results (Kruskal--Wallis) per performance variable, comparing by {group_col}. Reports $p$-value and effect size $\\epsilon^2$ (epsilon-squared).}}")
    latex_lines.append(f"\\label{{tab:kw-{group_col.lower()}}}")
    latex_lines.append(r"\begin{tabular}{lrrrr}")
    latex_lines.append(r"\toprule")
    latex_lines.append(r"\textbf{Variable} & \textbf{Groups (k)} & \textbf{N} & \textbf{$p$ (KW)} & \textbf{$\epsilon^2$} \\")
    latex_lines.append(r"\midrule")

    for _, r in kw_df.iterrows():
        var = escape_latex(r["Variable"])
        k = int(r["Groups (k)"]) if pd.notna(r["Groups (k)"]) else 0
        N = int(r["N"]) if pd.notna(r["N"]) else 0
        p = fmt_p(r["p (KW)"])
        eps = fmt_eps(r["epsilon^2"])
        latex_lines.append(f"{var} & {k} & {N} & {p} & {eps} \\\\")

    latex_lines.append(r"\bottomrule")
    latex_lines.append(r"\end{tabular}")
    latex_lines.append(r"\end{table}")

    latex_table = "\n".join(latex_lines)

    print(f"\n=== LaTeX for {group_col} ===\n")
    print(latex_table)
    print("\n")

print("\n" + "="*80)
print("COMPLETED!")
print("="*80)
# Out:
# Loading file: data.csv
# Columns found: ['Turma', 'MBTI', 'YEAR', 'GENDER', 'REQ', 'DEV', 'PROVA', 'NOTA FINAL', 'Group', 'Profile']
# Rows: 102
#
# Outcome columns found: ['REQ', 'DEV', 'PROVA', 'NOTA FINAL']
#
# ...
# ANALYSIS BY: Group
# ...
#
# === Kruskal–Wallis Summary: Group ===
#                Variable  Groups (k)    N    p (KW)  epsilon^2  \
# 0       Nota Requisitos           4  102  0.249548   0.011354
# 1  Nota Desenvolvimento           4  102  0.769247   0.000000
# 2         Prova Teórica           4  102  0.786363   0.000000
# 3            Nota Final           4  102  0.619489   0.000000
#
#                                       Groups found
# 0  Analistas, Diplomatas, Exploradores, Sentinelas
# 1  Analistas, Diplomatas, Exploradores, Sentinelas
# 2  Analistas, Diplomatas, Exploradores, Sentinelas
# 3  Analistas, Diplomatas, Exploradores, Sentinelas
# === LaTeX for Group ===
#
# \begin{table}[t]
# \centering
# \small
# ...
